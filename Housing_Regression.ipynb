# %% [markdown]
# <a href="https://colab.research.google.com/github/BindiyaB/DataSciencePractice/blob/master/Housing_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

from sklearn.pipeline import Pipeline

# %%
#url="https://github.com/BindiyaB/DataSciencePractice/blob/master/train_housing.csv"
#df1 = pd.read_csv(url)

# %%
train_df = pd.read_csv("train_housing.csv")

# %%
train_df.shape
# Out:
# (1460, 81)

# %%
train_df.head(10)
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
# 5   6          50       RL  ...        WD         Normal    143000
# 6   7          20       RL  ...        WD         Normal    307000
# 7   8          60       RL  ...        WD         Normal    200000
# 8   9          50       RM  ...        WD        Abnorml    129900
# 9  10         190       RL  ...        WD         Normal    118000
#
# [10 rows x 81 columns]

# %%
train_df.describe(include='all')
# Out:
#                  Id   MSSubClass  ... SaleCondition      SalePrice
# count   1460.000000  1460.000000  ...          1460    1460.000000
# unique          NaN          NaN  ...             6            NaN
# top             NaN          NaN  ...        Normal            NaN
# freq            NaN          NaN  ...          1198            NaN
# mean     730.500000    56.897260  ...           NaN  180921.195890
# std      421.610009    42.300571  ...           NaN   79442.502883
# min        1.000000    20.000000  ...           NaN   34900.000000
# 25%      365.750000    20.000000  ...           NaN  129975.000000
# 50%      730.500000    50.000000  ...           NaN  163000.000000
# 75%     1095.250000    70.000000  ...           NaN  214000.000000
# max     1460.000000   190.000000  ...           NaN  755000.000000
#
# [11 rows x 81 columns]

# %%
nulls=train_df.isnull().sum()
z=nulls[nulls>0]
z = (z/1460)*100
remove_cols = z[z>70].index
remove_cols
train_df.drop(remove_cols,axis=1,inplace=True)

# %%
train_df.columns
train_df.shape
# Out:
# (1460, 77)

# %%
corr = train_df.corr().abs()
corr
# Out:
#                      Id  MSSubClass  LotFrontage  ...    MoSold    YrSold  SalePrice
# Id             1.000000    0.011156     0.010601  ...  0.021172  0.000712   0.021917
# MSSubClass     0.011156    1.000000     0.386347  ...  0.013585  0.021407   0.084284
# LotFrontage    0.010601    0.386347     1.000000  ...  0.011200  0.007450   0.351799
# LotArea        0.033226    0.139781     0.426095  ...  0.001205  0.014261   0.263843
# OverallQual    0.028365    0.032628     0.251646  ...  0.070815  0.027347   0.790982
# OverallCond    0.012609    0.059316     0.059213  ...  0.003511  0.043950   0.077856
# YearBuilt      0.012713    0.027850     0.123349  ...  0.012398  0.013618   0.522897
# YearRemodAdd   0.021998    0.040581     0.088866  ...  0.021490  0.035743   0.507101
# MasVnrArea     0.050298    0.022936     0.193458  ...  0.005965  0.008201   0.477493
# BsmtFinSF1     0.005024    0.069836     0.233633  ...  0.015727  0.014359   0.386420
# ...

# %%
mask = np.zeros_like(corr,bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr,mask=mask)
